# %% [markdown]
# # Final Report

# %% [markdown]
# ## Introduction.

# %% [markdown]
# # In our exciting quest to find the Best Neighborhood in the whole wide greater Pittsburgh Area we first needed to decide what factors are most important when deciding what the best Neighborhood in Pittsburgh is.

# %% [markdown]
# #### 1. Environmental Factors:
#
#   Quality of Life, Air Quality, Parks.
# #### 2. Financial Factors:
#
#   Wealth of Neighborhood, Better Schools, Better Facilities.
# #### 3. Housing:
#
#   Public safety, Aesthetic

# %% [markdown]
# ## How can we quantify these seemingly Qualatative Data sets?

# %% [markdown]
# ### Data Sets

# %% [markdown]
# ### Enviromental Factors

# %% [markdown]
# Financial Factors can be measured in many different ways, we decided that the best way to measure ours was to simply take the Median house hold income of each Neighborhood and Rank that in order to get a general understanding of the wealth of the Neighborhood.

# %% [markdown]
# "https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/f7b19c6c-aa66-419b-b0e1-9998d7ddfcbc/download/education-income.csv"

# %%
##Importing the data set. 

import pandas as pd

income = pd.read_csv("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/f7b19c6c-aa66-419b-b0e1-9998d7ddfcbc/download/education-income.csv")
income.head(90)
# Out:
#            Neighborhood  Sector # Population (2010)  \
# 0      Allegheny Center         3               933
# 1        Allegheny West         3               462
# 2             Allentown         6             2,500
# 3             Arlington         7             1,869
# 4     Arlington Heights         7               244
# ..                  ...       ...               ...
# 85  Upper Lawrenceville        13             2,669
# 86             West End         4               254
# 87         West Oakland        14             2,604
# 88             Westwood         4             3,066
# 89              Windgap         4             1,369
#
#    Total Pop, 25 and older (2010)  \
# 0                             609
# 1                             239
# 2                           1,729
# 3                           1,232
# 4                             166
# ..                            ...
# 85                          1,875
# 86                             86
# ...

# %%
##Sorting the Values by the value of Median Income.

median_income=income.sort_values("2009 Med. Income ('13 Dollars)",ascending=False)  

##Setting Index to Neighborhood to better represent our metric.
median_income=median_income.set_index('Neighborhood')
median_income.head(90)
# Out:
#                      Sector # Population (2010)  \
# Neighborhood
# Point Breeze               10             5,315
# Squirrel Hill North        10            11,363
# New Homestead               8               990
# North Shore                16               303
# Regent Square              10               928
# ...                       ...               ...
# Bluff                      15             6,600
# Terrace Village            15             3,228
# Bedford Dwellings          15             1,202
# Arlington Heights           7               244
# Chateau                     3                11
#
#                     Total Pop, 25 and older (2010)  \
# Neighborhood
# Point Breeze                                 4,322
# Squirrel Hill North                          6,207
# New Homestead                                  923
# North Shore                                    196
# Regent Square                                  909
# ...

# %%
##Taking the First 5 Neighborhoods.

median_income.head(5)
# Out:
#                      Sector # Population (2010)  \
# Neighborhood
# Point Breeze               10             5,315
# Squirrel Hill North        10            11,363
# New Homestead               8               990
# North Shore                16               303
# Regent Square              10               928
#
#                     Total Pop, 25 and older (2010)  \
# Neighborhood
# Point Breeze                                 4,322
# Squirrel Hill North                          6,207
# New Homestead                                  923
# North Shore                                    196
# Regent Square                                  909
#
#                     Edu. Attainment: Less than High School (2010)  \
# Neighborhood
# Point Breeze                                                 5.0%
# Squirrel Hill North                                          1.8%
# New Homestead                                               10.1%
# ...

# %% [markdown]
# ### Combining the Metrics

# %% [markdown]
# #### Our three metrics take many different factors and put them into one quantifable metrics

# %% [markdown]
# Our Original plan was to Rank each of the Neighborhoods by their factors separately in order to make this process easier.Then combine the rankings of Each of the Neighborhoods in order to get a overall metric to grade the neighborhoods based on our factors.So if a neighborhood ranks number one in all 3 metrics. Their final score would be 3. Making them the best neighborhood.The worst possible score would be 270(90th place finishes in each Neighborhood.)

# %% [markdown]
# # But our plans were Compromised

# %% [markdown]
# ### The Housing Metric produced results that made our potential combined metric not very representative of the data set.

# %% [markdown]
# The Housing Metric provided A lot of first place ties for the best Neighborhood. We took some time to ponder what to do next. In the end we decided we would use the Housing Metric to set a standard for the rest of the Neighborhoods. If the Housing Rating of a given Neighborhood was not 0, it could no longer be in the running for the best Neighborhood.

# %% [markdown]
# Next we decided to look at the highest ranked Neighborhoods according to the Enviromental and Financial Metric.

# %%
median_income.head(10)
# Out:
#                      Sector # Population (2010)  \
# Neighborhood
# Point Breeze               10             5,315
# Squirrel Hill North        10            11,363
# New Homestead               8               990
# North Shore                16               303
# Regent Square              10               928
# Swisshelm Park             10             1,361
# Strip District             13               616
# Highland Park              12             6,395
# Ridgemont                   4               483
# Squirrel Hill South        10            15,110
#
#                     Total Pop, 25 and older (2010)  \
# Neighborhood
# Point Breeze                                 4,322
# Squirrel Hill North                          6,207
# New Homestead                                  923
# North Shore                                    196
# Regent Square                                  909
# Swisshelm Park                               1,110
# ...

# %%
**Insert Enviromental Metric here.

# %% [markdown]
# We noticed that the Neighborhood of North Shore was ranked 4th in the Financial Metric and 6th in the Enviromental Metric.

# %% [markdown]
# North Shore also had a perfect  0 for its housing Rating.

# %% [markdown]
# ### So using this data we have determined that the Best Neighborhood in Pittsburgh is

# %% [markdown]
# # North Shore

# %% [markdown]
# ### Ben's Conclusion

# %% [markdown]
# Our data driven conclusion I think did a great job in taking the a lot of information, and boiling them down into general metrics, that when combined really represents a summary of what the best Neighborhood of Pittsburgh is. We wanted to choose completely different metrics that represent completely different aspects of what goes into a good neighborhood. This way we are working with data from a variety of places. Our Housing data, Enviromental Data, and Financial data when combined provide a quick overview of many different factors given. In terms of weighting which factors are the most important, we took a more unorthodox approach. Like stated earlier the housing data was used a "weed out" metric meaning that if a Neighborhood did not have a perfect rating in terms of housing then it is not in contention for best Neighborhood. We weighted this as the most important because this standard was relatively easy for a Neighborhood to pass, so a Neighborhood not passing it speaks a lot to the government and management of that Neighborhood. The Enviromental and Financial Ratings were rating evenly. We were able to identify one Neighborhood that was among the top finishers in both metrics making it an easy choice to decide which Neighborhood was the best. All in all I think that our metrics provided a very good estimate of the best Neighborhood in Pittsburgh.
